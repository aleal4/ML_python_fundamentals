# %%
import pandas as pd
df=pd.read_csv('Chapter2_Shale_Gas_Wells_DataSet.csv')

# %%
df-df.describe()
# Out:
#        Stage Spacing  bbl/ft  Well Spacing  Dip  Thickness  Lateral Length  \
# 0                NaN     NaN           NaN  NaN        NaN             NaN
# 1                NaN     NaN           NaN  NaN        NaN             NaN
# 2                NaN     NaN           NaN  NaN        NaN             NaN
# 3                NaN     NaN           NaN  NaN        NaN             NaN
# 4                NaN     NaN           NaN  NaN        NaN             NaN
# ...              ...     ...           ...  ...        ...             ...
# count            NaN     NaN           NaN  NaN        NaN             NaN
# max              NaN     NaN           NaN  NaN        NaN             NaN
# mean             NaN     NaN           NaN  NaN        NaN             NaN
# min              NaN     NaN           NaN  NaN        NaN             NaN
# std              NaN     NaN           NaN  NaN        NaN             NaN
#
#        Injection Rate  Porosity  ISIP  Water Saturation  Percentage of LG  \
# 0                 NaN       NaN   NaN               NaN               NaN
# 1                 NaN       NaN   NaN               NaN               NaN
# 2                 NaN       NaN   NaN               NaN               NaN
# 3                 NaN       NaN   NaN               NaN               NaN
# 4                 NaN       NaN   NaN               NaN               NaN
# ...               ...       ...   ...               ...               ...
# count             NaN       NaN   NaN               NaN               NaN
# max               NaN       NaN   NaN               NaN               NaN
# mean              NaN       NaN   NaN               NaN               NaN
# min               NaN       NaN   NaN               NaN               NaN
# std               NaN       NaN   NaN               NaN               NaN
#
#        Pressure Gradient  Proppant Loading  EUR
# 0                    NaN               NaN  NaN
# 1                    NaN               NaN  NaN
# 2                    NaN               NaN  NaN
# 3                    NaN               NaN  NaN
# 4                    NaN               NaN  NaN
# ...                  ...               ...  ...
# count                NaN               NaN  NaN
# max                  NaN               NaN  NaN
# mean                 NaN               NaN  NaN
# min                  NaN               NaN  NaN
# std                  NaN               NaN  NaN
#
# [514 rows x 14 columns]

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_ng=pd.read_csv('Chapter2_Natural_Gas_Pricing_DataSet.csv', parse_dates=['Date'],index_col=['Date'])
df_ng.head()
# Out:
# /var/folders/y6/fxl5q2qn5kg2cd_4j_k391qm0000gn/T/ipykernel_58050/374281848.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_ng=pd.read_csv('Chapter2_Natural_Gas_Pricing_DataSet.csv', parse_dates=['Date'],index_col=['Date'])
#             Value
# Date
# 1997-01-01   5.25
# 1997-02-01   2.86
# 1997-03-01   2.95
# 1997-04-01   3.45
# 1997-05-01   3.57

# %%
fig=plt.figure(figsize=(10,10), dpi=90)
plt.plot(df_ng.index.values,df_ng['Value'], color='red')
plt.xlabel('Date')
plt.ylabel('Gas Pricing, $/MMBTU')
plt.title('Gas Pricing Vs. Date')
plt.show()

# %%
g=np.linspace(1,10,5)
h=g**2
fig=plt.figure(figsize=(10,10))
ax=fig.add_axes([0,0,1,1])
ax.plot(g,h,color='#FF8C00', linewidth=3, linestyle='-.', alpha=1, marker='o', markersize=10, markerfacecolor='green', markeredgewidth=3, markeredgecolor='red')
ax.set_xlabel('Time')
ax.set_ylabel('Pricing')
ax.set_title('Time Vs. Pricing')
ax.set_xlim([0,8])
ax.set_ylim([0,80])
plt.rc('font', size=18)
plt.rc('axes', titlesize=18) # Fontsize of the axes title
plt.rc('axes', labelsize=18) 
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
plt.rc('legend', fontsize=18)
plt.rc('figure', titlesize=18)
ax.text(3,3,'Commodity Pricing Plot', fontsize=30, color='red')
plt.show()

# %%
df=pd.read_csv('Chapter2
# Out:
# '/Users/augusto/Desktop/ML_python/Chapter2'
