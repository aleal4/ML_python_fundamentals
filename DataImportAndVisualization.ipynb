# %%
import pandas as pd
df=pd.read_csv('Chapter2_Shale_Gas_Wells_DataSet.csv')

# %%
df=df.describe()
df.to_csv('Shale Gas Wells Description.csv', index=False)

# %%
import pandas as pd
df=pd.read_html('https://www.eia.gov/dnav/ng/hist/n9190us3m.htm')

# %%
df
# Out:
# [                                                   0
#  0  View History: Monthly Annual Download Data (XL...
#  1  U.S. Natural Gas Wellhead Price (Dollars per T...,
#                                0                         1
#  0  View History: Monthly Annual  Download Data (XLS File),
#                                0
#  0  View History: Monthly Annual,
#                 0   1        2   3       4
#  0  View History: NaN  Monthly NaN  Annual,
#        Year   Jan   Feb   Mar   Apr   May   Jun   Jul  Aug  Sep   Oct   Nov  \
#  0   1973.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#  1   1974.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#  2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#  3   1975.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#  4   1976.0  0.54  0.54  0.54  0.55  0.55  0.58  0.58  0.6  0.6  0.62  0.63
#  ..     ...   ...   ...   ...   ...   ...   ...   ...  ...  ...   ...   ...
#  59  2022.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#  60  2023.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#  61  2024.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#  62     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#  63  2025.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  NaN   NaN   NaN
#
#       Dec
#  0    NaN
#  1    NaN
#  2    NaN
#  3    NaN
#  4   0.64
#  ..   ...
#  59   NaN
#  60   NaN
#  61   NaN
#  62   NaN
#  63   NaN
#
#  [64 rows x 13 columns],
#                                                     0
#  0  - = No Data Reported; -- = Not Applicable; NA ...,
#                                0
#  0       Release Date: 3/31/2025
#  1  Next Release Date: 4/30/2025]

# %%
from sqlalchemy import create_engine
engine=create_engine('sqlite:///:memory:')

# %%
pwd
# Out:
# '/Users/augusto/Desktop/ML_python'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
x=np.linspace(0,10,100)
y=x**3

# %%
plt.plot(x,y,'red',linewidth=4,linestyle='--')
plt.xlabel('Time')
plt.ylabel('Number of iterations')
plt.title('Number of Iterations Vs. Time')
plt.show()

# %%
fig=plt.figure(figsize=(10,5))
plt.subplot(1,3,1)
plt.plot(x,y,'b')
plt.title('Plot 1')
plt.subplot(1,3,2)
plt.plot(y*2,x**2,'r')
plt.title('Plot 2')
plt.subplot(1,3,3)
plt.plot(x,y,'purple')
plt.title('Plot 3')
plt.show()

# %%
fig=plt.figure()
fig=plt.figure(figsize=(10,6))
fig1=fig.add_axes([0.1,0.1,0.8,0.8])
fig2=fig.add_axes([0.2,0.6,0.3,0.2])
fig1.plot(x,y)
fig1.set_title('Large Plot')
fig1.set_xlabel('Time')
fig1.set_ylabel('Number of iteration')
fig2.plot(x*2,y)
fig2.set_title('Small Plot')
fig2.set_xlabel('Time')
fig2.set_ylabel('Number of iteration')
plt.show()

# %%
fig,axes=plt.subplots(nrows=2, ncols=2,figsize=(5,5),dpi=100)
axes[0,0].plot(x,y)
axes[0,0].set_title('Plot 1')
axes[0,0].set_xlabel('Time')
axes[0,0].set_ylabel('Production 1')
axes[0,1].plot(y,x)
axes[0,1].set_title('Plot 2')
axes[0,1].set_xlabel('Time')
axes[0,1].set_ylabel('Production 2')
axes[1,0].plot(y,x**2)
axes[1,0].set_title('Plot 3')
axes[1,0].set_xlabel('Time')
axes[1,0].set_ylabel('Production 3')
axes[1,1].plot(x,y**2)
axes[1,1].set_title('Plot 4')
axes[1,1].set_xlabel('Time')
axes[1,1].set_ylabel('Production 4')
plt.tight_layout()

# %%
plt.show()

# %%
df=df.describe()
df.to_csv('Shale Gas Wells Description.csv', index=False)
